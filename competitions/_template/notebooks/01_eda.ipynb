# %% [markdown]
# # 🔍 Exploratory Data Analysis
#
# > Competition: {{ COMPETITION_NAME }}
#
# ---

# %% [markdown]
# ## 📦 Setup

# %%
import sys
sys.path.append('../../..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from shared.utils import set_seed, reduce_memory_usage
from shared.visualization import (
    setup_plotting,
    plot_target_distribution,
    plot_missing_values,
    plot_correlation_matrix,
    plot_numerical_distributions,
    plot_categorical_distributions
)
from shared.data import load_competition_data, get_feature_types

set_seed(42)
setup_plotting()

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 📂 Load Data

# %%
# Update paths as needed
COMPETITION_PATH = '.'
TARGET_COL = 'target'  # Update this

train, test = load_competition_data(COMPETITION_PATH)

# %%
print(f"Train shape: {train.shape}")
print(f"Test shape: {test.shape}")
print(f"\nTrain columns: {train.columns.tolist()}")

# %%
train.head()

# %%
train.info()

# %%
train.describe()

# %% [markdown]
# ## 🎯 Target Distribution

# %%
plot_target_distribution(train, TARGET_COL)

# %% [markdown]
# ## ❓ Missing Values

# %%
plot_missing_values(train)

# %% [markdown]
# ## 📊 Feature Types

# %%
feature_types = get_feature_types(train)
print(f"Numerical: {len(feature_types['numerical'])} columns")
print(f"Categorical: {len(feature_types['categorical'])} columns")
print(f"Datetime: {len(feature_types['datetime'])} columns")

# %% [markdown]
# ## 📈 Numerical Distributions

# %%
plot_numerical_distributions(train, feature_types['numerical'][:12])

# %% [markdown]
# ## 📊 Categorical Distributions

# %%
if feature_types['categorical']:
    plot_categorical_distributions(train, feature_types['categorical'][:9])

# %% [markdown]
# ## 🔗 Correlation Analysis

# %%
plot_correlation_matrix(train)

# %% [markdown]
# ## 💡 Key Insights
#
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ---
# **Next Steps**: Proceed to `02_preprocessing.ipynb`
